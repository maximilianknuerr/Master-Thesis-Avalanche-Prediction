# %%
import numpy as np
import pandas as pd

# %%
lawinen = pd.read_csv('data/Allg_Lawinen_Abgänge.csv')

# %%
import datetime as dt

lawinen['DATUM'] = lawinen['DATUM'].apply(lambda x: dt.datetime.strptime(x,'%Y-%m-%d %H:%M:%S') if type(x)==str else pd.NaT)
lawinen['ZEIT'] = lawinen['ZEIT'].apply(lambda x: dt.datetime.strptime(x,'%Y-%m-%d %H:%M:%S') if type(x)==str else pd.NaT)
lawinen
# Out:
#                     DATUM                ZEIT                 Lawinen_Art  \
# 0     1957-02-27 00:00:00 1899-12-30 00:00:00                 Grundlawine
# 1     1967-03-21 00:00:00 1899-12-30 00:00:00                 Staublawine
# 2     1967-04-05 00:00:00 1899-12-30 07:20:00                 Staublawine
# 3     1970-02-04 00:00:00 1899-12-30 00:00:00                 Staublawine
# 4     1970-02-22 00:00:00 1899-12-30 10:49:00                 Staublawine
# ...                   ...                 ...                         ...
# 4095  2022-02-03 00:00:00 2022-02-03 00:00:00  Lockerschneelawine trocken
# 4096                  NaT                 NaT                         NaN
# 4097  2022-02-08 00:00:00                 NaT   Schneebrettlawine trocken
# 4098                  NaT                 NaT                         NaN
# 4099  2022-02-08 00:00:00                 NaT   Schneebrettlawine trocken
#
#       GRNR Volumen              Wetter WIND_RCHTG  WIND_GSCHW  Temperatur  \
# 0     43.0     NaN  Schneefall schwach          S         2.0        -5.0
# 1     13.0     NaN             bewölkt         SW         3.0        -7.0
# 2     13.0     NaN    Schneefall mäßig         NE         6.0        -5.0
# 3     13.0     NaN    Schneefall mäßig         SE         2.0        -6.0
# 4     13.0     NaN       Schneetreiben         SE         3.0        -3.0
# ...    ...     ...                 ...        ...         ...         ...
# 4095   9.0  mittel                   0         NO         5.0         0.0
# 4096   NaN     NaN                 NaN        NaN         NaN         NaN
# 4097  33.0  mittel             bedeckt         SW        20.0        -7.0
# 4098  13.0     NaN                 NaN        NaN         NaN         NaN
# 4099  43.0   klein             bewölkt        270         5.7        -1.0
#
#       Schneehoehe  Neuschnee  Gefahr Bemerkung
# 0           280.0        4.0     0.0       NaN
# 1             0.0       10.0     0.0       NaN
# 2           320.0       25.0     NaN       NaN
# 3           118.0       32.0     NaN       NaN
# 4           170.0       25.0     NaN       NaN
# ...           ...        ...     ...       ...
# 4095          NaN        5.0     4.0       NaN
# 4096          NaN        NaN     NaN       NaN
# 4097        175.0       21.0     3.0       NaN
# 4098          NaN        NaN     NaN       NaN
# 4099        175.0       21.0     3.0       NaN
#
# [4100 rows x 13 columns]

# %%
lawinen.sort_values(by=['DATUM','ZEIT'],inplace=True)
lawinen
# Out:
#                     DATUM                ZEIT                Lawinen_Art  \
# 3486  0208-01-22 00:00:00                 NaT  Schneebrettlawine trocken
# 3493  0208-01-24 00:00:00                 NaT  Schneebrettlawine trocken
# 491   1944-01-04 00:00:00 1899-12-30 16:00:00  Schneebrettlawine trocken
# 317   1944-12-28 00:00:00 1899-12-30 10:30:00  Schneebrettlawine trocken
# 1212  1945-03-08 00:00:00 1899-12-30 22:00:00                Staublawine
# ...                   ...                 ...                        ...
# 3520                  NaT                 NaT     Lockerschneelawine naß
# 3700                  NaT                 NaT                        NaN
# 3952                  NaT                 NaT                        NaN
# 4096                  NaT                 NaT                        NaN
# 4098                  NaT                 NaT                        NaN
#
#       GRNR Volumen            Wetter WIND_RCHTG  WIND_GSCHW  Temperatur  \
# 3486  43.0  mittel  Schneefall mäßig        135         5.0        -3.0
# 3493  14.0   klein         wolkenlos        225         3.0         4.0
# 491   15.0     NaN               NaN        NaN         0.0         0.0
# 317    7.0     NaN               NaN        NaN         0.0         0.0
# 1212  25.0     NaN               NaN        NaN         0.0         0.0
# ...    ...     ...               ...        ...         ...         ...
# 3520  10.0  mittel           bedeckt        225         3.0         7.0
# 3700   NaN     NaN               NaN        NaN         NaN         2.0
# 3952  11.0     NaN               NaN        NaN         NaN         NaN
# 4096   NaN     NaN               NaN        NaN         NaN         NaN
# 4098  13.0     NaN               NaN        NaN         NaN         NaN
#
#       Schneehoehe  Neuschnee  Gefahr Bemerkung
# 3486        152.0       20.0     4.0       NaN
# 3493        156.0        0.0     3.0       NaN
# 491           0.0        0.0     0.0       NaN
# 317           0.0        0.0     0.0       NaN
# 1212          0.0        0.0     0.0       NaN
# ...           ...        ...     ...       ...
# 3520        160.0        0.0     2.0       NaN
# 3700        150.0        NaN     NaN       NaN
# 3952          NaN        NaN     NaN       NaN
# 4096          NaN        NaN     NaN       NaN
# 4098          NaN        NaN     NaN       NaN
#
# [4100 rows x 13 columns]

# %%
start = dt.datetime.strptime('1989-10-01 00:00:00', '%Y-%m-%d %H:%M:%S')
end = dt.datetime.strptime('2022-12-31 00:00:00', '%Y-%m-%d %H:%M:%S')
lawinen = lawinen.loc[(lawinen['DATUM'] > start) & (lawinen['DATUM'] < end)]
lawinen
# Out:
#                     DATUM       ZEIT                Lawinen_Art  GRNR Volumen  \
# 366   1990-01-17 00:00:00 1899-12-30     Lockerschneelawine naß  37.0   klein
# 426   1990-01-17 00:00:00 1899-12-30     Lockerschneelawine naß  37.0   klein
# 841   1990-01-17 00:00:00 1899-12-30     Lockerschneelawine naß  39.0   klein
# 1292  1990-01-17 00:00:00 1899-12-30     Lockerschneelawine naß  34.0   klein
# 1360  1990-01-17 00:00:00 1899-12-30     Lockerschneelawine naß  39.0   klein
# ...                   ...        ...                        ...   ...     ...
# 4091  2022-02-03 00:00:00        NaT  Schneebrettlawine trocken  33.0  mittel
# 4092  2022-02-03 00:00:00        NaT  Schneebrettlawine trocken  15.0   gross
# 4093  2022-02-03 00:00:00        NaT  Schneebrettlawine trocken  28.0  mittel
# 4097  2022-02-08 00:00:00        NaT  Schneebrettlawine trocken  33.0  mittel
# 4099  2022-02-08 00:00:00        NaT  Schneebrettlawine trocken  43.0   klein
#
#          Wetter WIND_RCHTG  WIND_GSCHW  Temperatur  Schneehoehe  Neuschnee  \
# 366   wolkenlos         SW        -8.0         2.0         17.0        NaN
# 426   wolkenlos         SW         8.0         2.0         17.0        NaN
# 841   wolkenlos         SW         8.0         2.0         17.0        NaN
# 1292  wolkenlos         SW         8.0         2.0         17.0        NaN
# 1360  wolkenlos         SW         8.0         2.0         17.0        NaN
# ...         ...        ...         ...         ...          ...        ...
# 4091    bedeckt         NO         1.0        -4.0        140.0       15.0
# 4092    bedeckt         NO         1.0        -4.0        140.0       15.0
# 4093    bedeckt         NO        -4.0        -4.0        140.0       15.0
# 4097    bedeckt         SW        20.0        -7.0        175.0       21.0
# 4099    bewölkt        270         5.7        -1.0        175.0       21.0
#
#       Gefahr Bemerkung
# 366      2.0       NaN
# 426      2.0       NaN
# 841      2.0       NaN
# 1292     2.0       NaN
# 1360     2.0       NaN
# ...      ...       ...
# 4091     4.0       NaN
# 4092     4.0       NaN
# 4093     4.0       NaN
# 4097     3.0       NaN
# 4099     3.0       NaN
#
# [3257 rows x 13 columns]

# %%
#lawinen_katalog = pd.read_csv('data/Allg_Lawinen_Katalog.csv')
#lawinen['Lawinen_Name'] = lawinen['GRNR'].apply(lambda x: lawinen_katalog.loc[lawinen_katalog['GRNR']==x]['Lawinenname'].values[0] if x <= 42 else 'Alle Lawinen')
#lawinen['Lawinen_Name']

# %%
kaplawstr = pd.read_csv('data/kaplawstr.csv' ,sep=';')
#lawinen = pd.merge(lawinen, lawinen['Lawinen_Name'].apply(lambda x: kaplawstr.loc[kaplawstr['Lawinenstrich']==x]), left_index=True, right_index=True)
#lawinen
lawinen = pd.merge(lawinen, kaplawstr, left_on='GRNR', right_on='ID')
lawinen
# Out:
#                     DATUM                ZEIT                 Lawinen_Art  \
# 0     1990-01-17 00:00:00 1899-12-30 00:00:00      Lockerschneelawine naß
# 1     1990-01-17 00:00:00 1899-12-30 00:00:00      Lockerschneelawine naß
# 2     1990-02-14 00:00:00 1899-12-30 00:00:00   Schneebrettlawine trocken
# 3     1990-02-15 00:00:00 1899-12-30 00:00:00  Lockerschneelawine trocken
# 4     1990-03-29 00:00:00 1899-12-30 00:00:00  Lockerschneelawine trocken
# ...                   ...                 ...                         ...
# 2723  2021-04-13 00:00:00                 NaT   Schneebrettlawine trocken
# 2724  2021-04-26 00:00:00                 NaT       Schneebrettlawine naß
# 2725  2021-05-11 00:00:00 1899-12-30 14:00:00       Schneebrettlawine naß
# 2726  2021-12-04 00:00:00 1899-12-30 09:00:00                 Staublawine
# 2727  2022-02-03 00:00:00                 NaT   Schneebrettlawine trocken
#
#       GRNR Volumen              Wetter WIND_RCHTG  WIND_GSCHW  Temperatur  \
# 0     37.0   klein           wolkenlos         SW        -8.0         2.0
# 1     37.0   klein           wolkenlos         SW         8.0         2.0
# 2     37.0   klein    Schneefall mäßig         NE        11.0        -1.0
# 3     37.0  mittel               Regen         SE        -5.0         NaN
# 4     37.0   klein  Schneefall schwach         SW        -1.5        -4.0
# ...    ...     ...                 ...        ...         ...         ...
# 2723  28.0  mittel    Schneefall mäßig        360         3.0        -5.0
# 2724  28.0  mittel           wolkenlos        180         2.0         6.0
# 2725  28.0  mittel                Föhn        180         9.0         9.0
# 2726  28.0  mittel             bedeckt        180         2.0        -1.0
# 2727  28.0  mittel             bedeckt         NO        -4.0        -4.0
#
#       Schneehoehe  ...  Code_neu    Lawinenstrich        Text           xoff  \
# 0            17.0  ...  50606037       Jägerrinne   Geißstein  401205.592779
# 1            17.0  ...  50606037       Jägerrinne   Geißstein  401205.592779
# 2            62.0  ...  50606037       Jägerrinne   Geißstein  401205.592779
# 3           102.0  ...  50606037       Jägerrinne   Geißstein  401205.592779
# 4           135.0  ...  50606037       Jägerrinne   Geißstein  401205.592779
# ...           ...  ...       ...              ...         ...            ...
# 2723        135.0  ...  50606028  Griesbachlawine  Winterkarl  401356.059692
# 2724        119.0  ...  50606028  Griesbachlawine  Winterkarl  401356.059692
# 2725         76.0  ...  50606028  Griesbachlawine  Winterkarl  401356.059692
# 2726         74.0  ...  50606028  Griesbachlawine  Winterkarl  401356.059692
# 2727        140.0  ...  50606028  Griesbachlawine  Winterkarl  401356.059692
#
#                yoff     Scale  ScaleW ScaleH OffX  OffY
# 0     226325.106509  9.025046     373    628  148   424
# 1     226325.106509  9.025046     373    628  148   424
# 2     226325.106509  9.025046     373    628  148   424
# 3     226325.106509  9.025046     373    628  148   424
# 4     226325.106509  9.025046     373    628  148   424
# ...             ...       ...     ...    ...  ...   ...
# 2723  226681.470933  8.296389     622    852  189   526
# 2724  226681.470933  8.296389     622    852  189   526
# 2725  226681.470933  8.296389     622    852  189   526
# 2726  226681.470933  8.296389     622    852  189   526
# 2727  226681.470933  8.296389     622    852  189   526
#
# [2728 rows x 26 columns]

# %%
#polygon = pd.read_csv('data/polygon.csv')
#lawinen['Lawinen_Name'] = lawinen['Code_neu'].apply(lambda x: polygon.loc[polygon['LawID']==x]['Lawinenname'].values[0])
#lawinen['Lawinen_Name']

# %%
TOPP = pd.read_csv('data/TOPP.csv')
TOPP
# Out:
#       Lawinencode      TEZCode    meanExpo  stdDevExpo  MinExpo  MaxExpo  \
# 0        70912203  70912203001  125.259176         NaN      NaN      NaN
# 1        70912203  70912203002  122.557243         NaN      NaN      NaN
# 2        70912203  70912203003   93.615872         NaN      NaN      NaN
# 3        70912203  70912203004   73.136667         NaN      NaN      NaN
# 4        70912203  70912203005   50.172883         NaN      NaN      NaN
# ...           ...          ...         ...         ...      ...      ...
# 1900     70903114  70903114255  320.630211         NaN      NaN      NaN
# 1901     70903115  70903115256  187.629606         NaN      NaN      NaN
# 1902     70903123  70903123257   25.126780         NaN      NaN      NaN
# 1903     70903107  70903107258   42.784451         NaN      NaN      NaN
# 1904     70903114  70903114259  285.374241         NaN      NaN      NaN
#
#       meanSlope  stdDevSlope  MinSlope  MaxSlope  ...  MaxSun85  MaxSun99  \
# 0       43.5393       5.9687   25.2201   55.7018  ...    8.1028    8.4150
# 1       37.3054       5.7078   21.9953   47.9376  ...    7.6175    8.9210
# 2       34.5118       5.8841   23.6521   57.4818  ...    7.9239    7.9783
# 3       34.5328       5.5097   25.6617   62.4592  ...    6.6960    7.8238
# 4       34.8550       3.8607   27.9332   48.6266  ...    6.3827    7.9964
# ...         ...          ...       ...       ...  ...       ...       ...
# 1900    38.9883       4.9080   31.8888   64.7424  ...    3.9924    5.4244
# 1901    42.6524       5.0782   32.3354   62.2187  ...    9.2767    9.9762
# 1902    31.1709       4.6480   22.7955   60.4927  ...    6.3477    7.8549
# 1903    34.3546       6.9285   21.7052   66.3576  ...    2.4720    5.0629
# 1904    43.6245       6.0381   30.7187   59.0417  ...    6.6693    7.0234
#
#       MaxSun113  MaxSun127  MaxSun310  MaxSun324  MaxSun338  MaxSun352  \
# 0        9.0553    10.0000     4.8142     4.7194     3.3241     3.0988
# 1        9.0000     9.5343     4.9938     4.3493     3.0000     3.0000
# 2        8.9783     9.9203     4.4167     3.5906     2.9112     2.6250
# 3        8.2763     9.4646     4.5337     2.9983     1.9413     1.9102
# 4        8.1588     9.8700     3.8773     2.6354     1.6606     1.2816
# ...         ...        ...        ...        ...        ...        ...
# 1900     7.1437     7.9647     0.2017     0.0345     0.0000     0.0000
# 1901    10.9182    11.1167     6.0307     6.0000     5.4354     5.3312
# 1902     9.1739    10.6193     0.0000     0.0000     0.0000     0.0000
# 1903     6.6189     8.1049     0.0000     0.0000     0.0000     0.0000
# 1904     8.3542     8.9297     2.5469     1.3802     0.6875     0.5052
#
#       HorÜb1  HorÜb2
# 0        NaN     NaN
# 1        NaN     NaN
# 2        NaN     NaN
# 3        NaN     NaN
# 4        NaN     NaN
# ...      ...     ...
# 1900     NaN     NaN
# 1901     NaN     NaN
# 1902     NaN     NaN
# 1903     NaN     NaN
# 1904     NaN     NaN
#
# [1905 rows x 44 columns]

# %%
TOPP = kaplawstr['Code_neu'].apply(lambda x: TOPP.loc[TOPP['Lawinencode'] == x].mean())

#TOPP = TOPP.groupby('Lawinencode').first().reset_index()

# %%
lawinen = pd.merge(lawinen, TOPP, left_on='Code_neu', right_on='Lawinencode')
lawinen
# Out:
#                     DATUM                ZEIT                 Lawinen_Art  \
# 0     1990-01-17 00:00:00 1899-12-30 00:00:00      Lockerschneelawine naß
# 1     1990-01-17 00:00:00 1899-12-30 00:00:00      Lockerschneelawine naß
# 2     1990-02-14 00:00:00 1899-12-30 00:00:00   Schneebrettlawine trocken
# 3     1990-02-15 00:00:00 1899-12-30 00:00:00  Lockerschneelawine trocken
# 4     1990-03-29 00:00:00 1899-12-30 00:00:00  Lockerschneelawine trocken
# ...                   ...                 ...                         ...
# 2723  2021-04-13 00:00:00                 NaT   Schneebrettlawine trocken
# 2724  2021-04-26 00:00:00                 NaT       Schneebrettlawine naß
# 2725  2021-05-11 00:00:00 1899-12-30 14:00:00       Schneebrettlawine naß
# 2726  2021-12-04 00:00:00 1899-12-30 09:00:00                 Staublawine
# 2727  2022-02-03 00:00:00                 NaT   Schneebrettlawine trocken
#
#       GRNR Volumen              Wetter WIND_RCHTG  WIND_GSCHW  Temperatur  \
# 0     37.0   klein           wolkenlos         SW        -8.0         2.0
# 1     37.0   klein           wolkenlos         SW         8.0         2.0
# 2     37.0   klein    Schneefall mäßig         NE        11.0        -1.0
# 3     37.0  mittel               Regen         SE        -5.0         NaN
# 4     37.0   klein  Schneefall schwach         SW        -1.5        -4.0
# ...    ...     ...                 ...        ...         ...         ...
# 2723  28.0  mittel    Schneefall mäßig        360         3.0        -5.0
# 2724  28.0  mittel           wolkenlos        180         2.0         6.0
# 2725  28.0  mittel                Föhn        180         9.0         9.0
# 2726  28.0  mittel             bedeckt        180         2.0        -1.0
# 2727  28.0  mittel             bedeckt         NO        -4.0        -4.0
#
#       Schneehoehe  ...  MaxSun85  MaxSun99 MaxSun113  MaxSun127 MaxSun310  \
# 0            17.0  ...  6.483550  7.171650  7.861488   8.795175  3.002912
# 1            17.0  ...  6.483550  7.171650  7.861488   8.795175  3.002912
# 2            62.0  ...  6.483550  7.171650  7.861488   8.795175  3.002912
# 3           102.0  ...  6.483550  7.171650  7.861488   8.795175  3.002912
# 4           135.0  ...  6.483550  7.171650  7.861488   8.795175  3.002912
# ...           ...  ...       ...       ...       ...        ...       ...
# 2723        135.0  ...  4.747158  6.514084  8.031405   9.002989  0.537895
# 2724        119.0  ...  4.747158  6.514084  8.031405   9.002989  0.537895
# 2725         76.0  ...  4.747158  6.514084  8.031405   9.002989  0.537895
# 2726         74.0  ...  4.747158  6.514084  8.031405   9.002989  0.537895
# 2727        140.0  ...  4.747158  6.514084  8.031405   9.002989  0.537895
#
#      MaxSun324  MaxSun338 MaxSun352 HorÜb1  HorÜb2
# 0     2.448925   2.101150  1.880138    NaN     NaN
# 1     2.448925   2.101150  1.880138    NaN     NaN
# 2     2.448925   2.101150  1.880138    NaN     NaN
# 3     2.448925   2.101150  1.880138    NaN     NaN
# 4     2.448925   2.101150  1.880138    NaN     NaN
# ...        ...        ...       ...    ...     ...
# 2723  0.322805   0.147005  0.104132    NaN     NaN
# 2724  0.322805   0.147005  0.104132    NaN     NaN
# 2725  0.322805   0.147005  0.104132    NaN     NaN
# 2726  0.322805   0.147005  0.104132    NaN     NaN
# 2727  0.322805   0.147005  0.104132    NaN     NaN
#
# [2728 rows x 70 columns]

# %%
lawinen.to_csv('newData/lawinen_abgänge.csv', index=True)

# %%
mooser_wetter_daten = pd.read_csv('data/Mooser_Wetter_Daten.csv')
mooser_wetter_daten
# Out:
#                     Datum    Intervall  Lawinengrad  Lawinengrad_Norm  \
# 0     1956-11-29 00:00:00   1956/ 1957            0                 0
# 1     1956-11-30 00:00:00   1956/ 1957            0                 0
# 2     1956-12-01 00:00:00   1956/ 1957            0                 0
# 3     1956-12-02 00:00:00   1956/ 1957           44                 0
# 4     1956-12-03 00:00:00   1956/ 1957            0                 0
# ...                   ...          ...          ...               ...
# 9573  2022-02-08 00:00:00   2021/ 2022           33                 0
# 9574  2022-02-09 00:00:00   2021/ 2022           33                 0
# 9575  2022-02-10 00:00:00   2021/ 2022           33                 0
# 9576  2022-02-11 00:00:00   2021/ 2022           22                 0
# 9577  2022-02-12 00:00:00   2021/ 2022           22                 0
#
#       Lawinengrad_Gew  Schneehöhe  Schneehöhe_Norm  Schneehöhe_Gew  \
# 0                   0         113       215.978593               0
# 1                   0         116       196.166855               0
# 2                   0         124       225.198638               0
# 3                   0         121       220.607735               0
# 4                   0         110       199.779857               0
# ...               ...         ...              ...             ...
# 9573                0         175       162.359178               0
# 9574                0         155       141.483293               0
# 9575                0         149       134.537246               0
# 9576                0         144       129.792371               0
# 9577                0         149       132.381406               0
#
#       Niederschlag  Niederschlag_Norm  ...  BW_FUZZY_Erg_Exp6  \
# 0              1.9                  0  ...                NaN
# 1              2.5                  0  ...                NaN
# 2              0.0                  0  ...                NaN
# 3              2.5                  0  ...                NaN
# 4             11.0                  0  ...                NaN
# ...            ...                ...  ...                ...
# 9573          16.0                  0  ...                0.0
# 9574           8.0                  0  ...                0.0
# 9575           0.0                  0  ...                0.0
# 9576           0.0                  0  ...                0.0
# 9577           7.0                  0  ...                0.0
#
#       BW_FUZZY_Erg_Exp7  BW_FUZZY_Regeln_Exp0  BW_FUZZY_Regeln_Exp1  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
# ...                 ...                   ...                   ...
# 9573                0.0                   NaN                   NaN
# 9574                0.0                   NaN                   NaN
# 9575                0.0                   NaN                   NaN
# 9576                0.0                   NaN                   NaN
# 9577                0.0                   NaN                   NaN
#
#       BW_FUZZY_Regeln_Exp2  BW_FUZZY_Regeln_Exp3  BW_FUZZY_Regeln_Exp4  \
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
# ...                    ...                   ...                   ...
# 9573                   NaN                   NaN                   NaN
# 9574                   NaN                   NaN                   NaN
# 9575                   NaN                   NaN                   NaN
# 9576                   NaN                   NaN                   NaN
# 9577                   NaN                   NaN                   NaN
#
#       BW_FUZZY_Regeln_Exp5  BW_FUZZY_Regeln_Exp6  BW_FUZZY_Regeln_Exp7
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
# ...                    ...                   ...                   ...
# 9573                   NaN                   NaN                   NaN
# 9574                   NaN                   NaN                   NaN
# 9575                   NaN                   NaN                   NaN
# 9576                   NaN                   NaN                   NaN
# 9577                   NaN                   NaN                   NaN
#
# [9578 rows x 69 columns]

# %%
mooser_wetter_daten['Datum'] = mooser_wetter_daten['Datum'].apply(lambda x: dt.datetime.strptime(x,'%Y-%m-%d %H:%M:%S') if type(x)==str else pd.NaT)
mooser_wetter_daten = mooser_wetter_daten.loc[(mooser_wetter_daten['Datum'] > start) & (mooser_wetter_daten['Datum'] < end)]
mooser_wetter_daten.reset_index(inplace=True, drop=True)
mooser_wetter_daten
# Out:
#           Datum    Intervall  Lawinengrad  Lawinengrad_Norm  Lawinengrad_Gew  \
# 0    1989-12-20   1989/ 1990            0                 0                0
# 1    1989-12-21   1989/ 1990            0                 0                0
# 2    1989-12-22   1989/ 1990            0                 0                0
# 3    1989-12-23   1989/ 1990            0                 0                0
# 4    1989-12-24   1989/ 1990            0                 0                0
# ...         ...          ...          ...               ...              ...
# 5325 2022-02-08   2021/ 2022           33                 0                0
# 5326 2022-02-09   2021/ 2022           33                 0                0
# 5327 2022-02-10   2021/ 2022           33                 0                0
# 5328 2022-02-11   2021/ 2022           22                 0                0
# 5329 2022-02-12   2021/ 2022           22                 0                0
#
#       Schneehöhe  Schneehöhe_Norm  Schneehöhe_Gew  Niederschlag  \
# 0             20        29.371271               0           0.0
# 1             19        26.654976               0           0.0
# 2             19        27.313567               0           9.1
# 3              4         5.611574               0           5.3
# 4             10        13.894920               0           7.3
# ...          ...              ...             ...           ...
# 5325         175       162.359178               0          16.0
# 5326         155       141.483293               0           8.0
# 5327         149       134.537246               0           0.0
# 5328         144       129.792371               0           0.0
# 5329         149       132.381406               0           7.0
#
#       Niederschlag_Norm  ...  BW_FUZZY_Erg_Exp6  BW_FUZZY_Erg_Exp7  \
# 0                     0  ...                NaN                NaN
# 1                     0  ...                NaN                NaN
# 2                     0  ...                NaN                NaN
# 3                     0  ...                NaN                NaN
# 4                     0  ...                NaN                NaN
# ...                 ...  ...                ...                ...
# 5325                  0  ...                0.0                0.0
# 5326                  0  ...                0.0                0.0
# 5327                  0  ...                0.0                0.0
# 5328                  0  ...                0.0                0.0
# 5329                  0  ...                0.0                0.0
#
#       BW_FUZZY_Regeln_Exp0  BW_FUZZY_Regeln_Exp1  BW_FUZZY_Regeln_Exp2  \
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
# ...                    ...                   ...                   ...
# 5325                   NaN                   NaN                   NaN
# 5326                   NaN                   NaN                   NaN
# 5327                   NaN                   NaN                   NaN
# 5328                   NaN                   NaN                   NaN
# 5329                   NaN                   NaN                   NaN
#
#       BW_FUZZY_Regeln_Exp3  BW_FUZZY_Regeln_Exp4  BW_FUZZY_Regeln_Exp5  \
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
# ...                    ...                   ...                   ...
# 5325                   NaN                   NaN                   NaN
# 5326                   NaN                   NaN                   NaN
# 5327                   NaN                   NaN                   NaN
# 5328                   NaN                   NaN                   NaN
# 5329                   NaN                   NaN                   NaN
#
#       BW_FUZZY_Regeln_Exp6  BW_FUZZY_Regeln_Exp7
# 0                      NaN                   NaN
# 1                      NaN                   NaN
# 2                      NaN                   NaN
# 3                      NaN                   NaN
# 4                      NaN                   NaN
# ...                    ...                   ...
# 5325                   NaN                   NaN
# 5326                   NaN                   NaN
# 5327                   NaN                   NaN
# 5328                   NaN                   NaN
# 5329                   NaN                   NaN
#
# [5330 rows x 69 columns]

# %%
import statistics
from math import isnan
for i in mooser_wetter_daten.index:
    j = i - 1
    Neuschnee_last2 = 0.0
    Neuschnee_last4 = 0.0


    windstaerke_last4 = []
    Lufttemperatur_last4 = []

    while mooser_wetter_daten.iloc[j]['Intervall'] == mooser_wetter_daten.iloc[i]['Intervall'] and j  >= 0  and j >= i - 10:
        if j >= i - 2:
            Neuschnee_last2 += mooser_wetter_daten.iloc[j]['Neuschnee_Norm']
        if j >= i - 4:
            Neuschnee_last4 += mooser_wetter_daten.iloc[j]['Neuschnee_Norm']
            windstaerke_last4.append(mooser_wetter_daten.iloc[j]['Windstärke_Norm'])
            Lufttemperatur_last4.append([mooser_wetter_daten.iloc[j]['Lufttemperatur_7h_Norm'], mooser_wetter_daten.iloc[j]['Lufttemperatur_14h_Norm'], mooser_wetter_daten.iloc[j]['Lufttemperatur_19h_Norm']])
        j -= 1

    mooser_wetter_daten.loc[i, 'Neuschnee_last4'] = Neuschnee_last4
    mooser_wetter_daten.loc[i, 'Neuschnee_last2'] = Neuschnee_last2
    if len(windstaerke_last4) > 0:
        for j in range(4):
            if len(windstaerke_last4) > j:
                mooser_wetter_daten.loc[i, 'windstaerke_last' + str(j + 1)] = windstaerke_last4[j]
            else:
                mooser_wetter_daten.loc[i, 'windstaerke_last' + str(j + 1)] = 0.0
    else:
        for j in range(4):
            mooser_wetter_daten.loc[i, 'windstaerke_last' + str(j + 1)] = 0.0
    if len(Lufttemperatur_last4) > 0:
        for j in range(4):
            if len(Lufttemperatur_last4) > j:
                mooser_wetter_daten.loc[i, 'Lufttemperatur_last' + str(j + 1)] = statistics.mean(Lufttemperatur_last4[j])
            else:
                mooser_wetter_daten.loc[i, 'Lufttemperatur_last' + str(j + 1)] = 0.0
    else:
        for j in range(4):
            mooser_wetter_daten.loc[i, 'Lufttemperatur_last' + str(j + 1)] = 0.0




mooser_wetter_daten
# Out:
# /Users/max/miniforge3/lib/python3.9/site-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/max/miniforge3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#           Datum    Intervall  Lawinengrad  Lawinengrad_Norm  Lawinengrad_Gew  \
# 0    1989-12-20   1989/ 1990            0                 0                0
# 1    1989-12-21   1989/ 1990            0                 0                0
# 2    1989-12-22   1989/ 1990            0                 0                0
# 3    1989-12-23   1989/ 1990            0                 0                0
# 4    1989-12-24   1989/ 1990            0                 0                0
# ...         ...          ...          ...               ...              ...
# 5325 2022-02-08   2021/ 2022           33                 0                0
# 5326 2022-02-09   2021/ 2022           33                 0                0
# 5327 2022-02-10   2021/ 2022           33                 0                0
# 5328 2022-02-11   2021/ 2022           22                 0                0
# 5329 2022-02-12   2021/ 2022           22                 0                0
#
#       Schneehöhe  Schneehöhe_Norm  Schneehöhe_Gew  Niederschlag  \
# 0             20        29.371271               0           0.0
# 1             19        26.654976               0           0.0
# 2             19        27.313567               0           9.1
# 3              4         5.611574               0           5.3
# 4             10        13.894920               0           7.3
# ...          ...              ...             ...           ...
# 5325         175       162.359178               0          16.0
# 5326         155       141.483293               0           8.0
# 5327         149       134.537246               0           0.0
# 5328         144       129.792371               0           0.0
# 5329         149       132.381406               0           7.0
#
#       Niederschlag_Norm  ...  Neuschnee_last4  Neuschnee_last2  \
# 0                     0  ...              0.0              0.0
# 1                     0  ...            200.0            200.0
# 2                     0  ...            200.0            200.0
# 3                     0  ...            200.0              0.0
# 4                     0  ...            220.0             20.0
# ...                 ...  ...              ...              ...
# 5325                  0  ...            100.0            100.0
# 5326                  0  ...            310.0            310.0
# 5327                  0  ...            310.0            210.0
# 5328                  0  ...            310.0              0.0
# 5329                  0  ...            210.0              0.0
#
#       windstaerke_last1  windstaerke_last2  windstaerke_last3  \
# 0          0.000000e+00       0.000000e+00       0.000000e+00
# 1          2.545584e+00       0.000000e+00       0.000000e+00
# 2         -3.674616e-11       2.545584e+00       0.000000e+00
# 3         -2.880000e+01      -3.674616e-11       2.545584e+00
# 4          2.204770e-10      -2.880000e+01      -3.674616e-11
# ...                 ...                ...                ...
# 5325       2.040742e+01      -3.693818e+00      -2.462545e+00
# 5326      -1.999376e+01       2.040742e+01      -3.693818e+00
# 5327      -1.571923e+01      -1.999376e+01       2.040742e+01
# 5328       0.000000e+00      -1.571923e+01      -1.999376e+01
# 5329      -1.069145e+01       0.000000e+00      -1.571923e+01
#
#       windstaerke_last4  Lufttemperatur_last1  Lufttemperatur_last2  \
# 0              0.000000              0.000000              0.000000
# 1              0.000000             15.466667              0.000000
# 2              0.000000             28.266667             15.466667
# 3              0.000000             40.000000             28.266667
# 4              2.545584            -48.000000             40.000000
# ...                 ...                   ...                   ...
# 5325          -6.942106            -80.000000            -40.000000
# 5326          -2.462545            -29.333333            -80.000000
# 5327          -3.693818             45.333333            -29.333333
# 5328          20.407424             -2.666667             45.333333
# 5329         -19.993760            -48.000000             -2.666667
#
#       Lufttemperatur_last3  Lufttemperatur_last4
# 0                 0.000000              0.000000
# 1                 0.000000              0.000000
# 2                 0.000000              0.000000
# 3                15.466667              0.000000
# 4                28.266667             15.466667
# ...                    ...                   ...
# 5325            -10.666667              2.666667
# 5326            -40.000000            -10.666667
# 5327            -80.000000            -40.000000
# 5328            -29.333333            -80.000000
# 5329             45.333333            -29.333333
#
# [5330 rows x 79 columns]

# %%
lawinen['DATUM'] = pd.to_datetime(lawinen['DATUM'])


gesamt_df = pd.merge(mooser_wetter_daten, lawinen, right_on='DATUM', left_on='Datum', how='outer')
gesamt_df
# Out:
#           Datum    Intervall  Lawinengrad  Lawinengrad_Norm  Lawinengrad_Gew  \
# 0    1989-12-20   1989/ 1990          0.0               0.0              0.0
# 1    1989-12-21   1989/ 1990          0.0               0.0              0.0
# 2    1989-12-22   1989/ 1990          0.0               0.0              0.0
# 3    1989-12-23   1989/ 1990          0.0               0.0              0.0
# 4    1989-12-24   1989/ 1990          0.0               0.0              0.0
# ...         ...          ...          ...               ...              ...
# 7050        NaT          NaN          NaN               NaN              NaN
# 7051        NaT          NaN          NaN               NaN              NaN
# 7052        NaT          NaN          NaN               NaN              NaN
# 7053        NaT          NaN          NaN               NaN              NaN
# 7054        NaT          NaN          NaN               NaN              NaN
#
#       Schneehöhe  Schneehöhe_Norm  Schneehöhe_Gew  Niederschlag  \
# 0           20.0        29.371271             0.0           0.0
# 1           19.0        26.654976             0.0           0.0
# 2           19.0        27.313567             0.0           9.1
# 3            4.0         5.611574             0.0           5.3
# 4           10.0        13.894920             0.0           7.3
# ...          ...              ...             ...           ...
# 7050         NaN              NaN             NaN           NaN
# 7051         NaN              NaN             NaN           NaN
# 7052         NaN              NaN             NaN           NaN
# 7053         NaN              NaN             NaN           NaN
# 7054         NaN              NaN             NaN           NaN
#
#       Niederschlag_Norm  ...  MaxSun85  MaxSun99  MaxSun113  MaxSun127  \
# 0                   0.0  ...       NaN       NaN        NaN        NaN
# 1                   0.0  ...       NaN       NaN        NaN        NaN
# 2                   0.0  ...       NaN       NaN        NaN        NaN
# 3                   0.0  ...       NaN       NaN        NaN        NaN
# 4                   0.0  ...       NaN       NaN        NaN        NaN
# ...                 ...  ...       ...       ...        ...        ...
# 7050                NaN  ...  7.239245  8.341709   9.413709  10.100955
# 7051                NaN  ...  7.265034  8.387445   9.264609   9.822104
# 7052                NaN  ...  4.429150  5.565675   7.096475   8.137075
# 7053                NaN  ...  6.507130  7.626766   8.777404   9.595887
# 7054                NaN  ...  7.353688  8.634925   9.208600  10.026750
#
#       MaxSun310  MaxSun324  MaxSun338  MaxSun352  HorÜb1  HorÜb2
# 0           NaN        NaN        NaN        NaN     NaN     NaN
# 1           NaN        NaN        NaN        NaN     NaN     NaN
# 2           NaN        NaN        NaN        NaN     NaN     NaN
# 3           NaN        NaN        NaN        NaN     NaN     NaN
# 4           NaN        NaN        NaN        NaN     NaN     NaN
# ...         ...        ...        ...        ...     ...     ...
# 7050   2.240755   1.753445   1.602236   1.387627     NaN     NaN
# 7051   3.705030   3.168662   2.706613   2.574883     NaN     NaN
# 7052   1.042079   0.591500   0.535793   0.449786     NaN     NaN
# 7053   3.077736   2.601575   2.547768   2.391418     NaN     NaN
# 7054   3.754812   2.869875   2.894463   2.712263     NaN     NaN
#
# [7055 rows x 149 columns]

# %%
#gesamt_df['meanExpo'].replace(np.nan, TOPP.sample(1)['meanExpo'].values[0], inplace=True)

for i in gesamt_df.index:
    if(pd.isnull(gesamt_df['meanExpo'][i])):
        sample = TOPP.sample(1)
        gesamt_df['meanExpo'][i] = sample['meanExpo'].values[0]
        gesamt_df['meanSlope'][i] = sample['meanSlope'].values[0]
        gesamt_df['stdDevSlope'][i] = sample['stdDevSlope'].values[0]
        gesamt_df['MinSlope'][i] = sample['MinSlope'].values[0]
        gesamt_df['MaxSlope'][i] = sample['MaxSlope'].values[0]
        gesamt_df['Altitude'][i] = sample['Altitude'].values[0]
gesamt_df
# Out:
# /var/folders/xc/49zm43dj0sdcz0pp9m82j7gh0000gn/T/ipykernel_15055/1747414703.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gesamt_df['meanExpo'][i] = sample['meanExpo'].values[0]
# /var/folders/xc/49zm43dj0sdcz0pp9m82j7gh0000gn/T/ipykernel_15055/1747414703.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gesamt_df['meanSlope'][i] = sample['meanSlope'].values[0]
# /var/folders/xc/49zm43dj0sdcz0pp9m82j7gh0000gn/T/ipykernel_15055/1747414703.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gesamt_df['stdDevSlope'][i] = sample['stdDevSlope'].values[0]
# /var/folders/xc/49zm43dj0sdcz0pp9m82j7gh0000gn/T/ipykernel_15055/1747414703.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gesamt_df['MinSlope'][i] = sample['MinSlope'].values[0]
# /var/folders/xc/49zm43dj0sdcz0pp9m82j7gh0000gn/T/ipykernel_15055/1747414703.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gesamt_df['MaxSlope'][i] = sample['MaxSlope'].values[0]
# /var/folders/xc/49zm43dj0sdcz0pp9m82j7gh0000gn/T/ipykernel_15055/1747414703.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gesamt_df['Altitude'][i] = sample['Altitude'].values[0]
#           Datum    Intervall  Lawinengrad  Lawinengrad_Norm  Lawinengrad_Gew  \
# 0    1989-12-20   1989/ 1990          0.0               0.0              0.0
# 1    1989-12-21   1989/ 1990          0.0               0.0              0.0
# 2    1989-12-22   1989/ 1990          0.0               0.0              0.0
# 3    1989-12-23   1989/ 1990          0.0               0.0              0.0
# 4    1989-12-24   1989/ 1990          0.0               0.0              0.0
# ...         ...          ...          ...               ...              ...
# 7050        NaT          NaN          NaN               NaN              NaN
# 7051        NaT          NaN          NaN               NaN              NaN
# 7052        NaT          NaN          NaN               NaN              NaN
# 7053        NaT          NaN          NaN               NaN              NaN
# 7054        NaT          NaN          NaN               NaN              NaN
#
#       Schneehöhe  Schneehöhe_Norm  Schneehöhe_Gew  Niederschlag  \
# 0           20.0        29.371271             0.0           0.0
# 1           19.0        26.654976             0.0           0.0
# 2           19.0        27.313567             0.0           9.1
# 3            4.0         5.611574             0.0           5.3
# 4           10.0        13.894920             0.0           7.3
# ...          ...              ...             ...           ...
# 7050         NaN              NaN             NaN           NaN
# 7051         NaN              NaN             NaN           NaN
# 7052         NaN              NaN             NaN           NaN
# 7053         NaN              NaN             NaN           NaN
# 7054         NaN              NaN             NaN           NaN
#
#       Niederschlag_Norm  ...  MaxSun85  MaxSun99  MaxSun113  MaxSun127  \
# 0                   0.0  ...       NaN       NaN        NaN        NaN
# 1                   0.0  ...       NaN       NaN        NaN        NaN
# 2                   0.0  ...       NaN       NaN        NaN        NaN
# 3                   0.0  ...       NaN       NaN        NaN        NaN
# 4                   0.0  ...       NaN       NaN        NaN        NaN
# ...                 ...  ...       ...       ...        ...        ...
# 7050                NaN  ...  7.239245  8.341709   9.413709  10.100955
# 7051                NaN  ...  7.265034  8.387445   9.264609   9.822104
# 7052                NaN  ...  4.429150  5.565675   7.096475   8.137075
# 7053                NaN  ...  6.507130  7.626766   8.777404   9.595887
# 7054                NaN  ...  7.353688  8.634925   9.208600  10.026750
#
#       MaxSun310  MaxSun324  MaxSun338  MaxSun352  HorÜb1  HorÜb2
# 0           NaN        NaN        NaN        NaN     NaN     NaN
# 1           NaN        NaN        NaN        NaN     NaN     NaN
# 2           NaN        NaN        NaN        NaN     NaN     NaN
# 3           NaN        NaN        NaN        NaN     NaN     NaN
# 4           NaN        NaN        NaN        NaN     NaN     NaN
# ...         ...        ...        ...        ...     ...     ...
# 7050   2.240755   1.753445   1.602236   1.387627     NaN     NaN
# 7051   3.705030   3.168662   2.706613   2.574883     NaN     NaN
# 7052   1.042079   0.591500   0.535793   0.449786     NaN     NaN
# 7053   3.077736   2.601575   2.547768   2.391418     NaN     NaN
# 7054   3.754812   2.869875   2.894463   2.712263     NaN     NaN
#
# [7055 rows x 149 columns]

# %%
import seaborn as sns
sns.set(rc = {'figure.figsize':(10,10)})
sns.heatmap(gesamt_df.isna())
# Out:
# <AxesSubplot:>

# %%
gesamt_df = gesamt_df.drop([ 'Lawinengrad','Lawinengrad_Norm','Lawinenabgänge', 'Lawinengrad_Gew','Lawinenabgänge_Norm','Lawinenabgänge_Gew','Winterphase','Winterphase_Norm','Winterphase_Gew','BW_FUZZY_Erg','BW_FUZZY_Regeln','BW_FUZZY_Erg_Exp0','BW_FUZZY_Erg_Exp1','BW_FUZZY_Erg_Exp2','BW_FUZZY_Erg_Exp3','BW_FUZZY_Erg_Exp4','BW_FUZZY_Erg_Exp5','BW_FUZZY_Erg_Exp6','BW_FUZZY_Erg_Exp7','BW_FUZZY_Regeln_Exp0','BW_FUZZY_Regeln_Exp1','BW_FUZZY_Regeln_Exp2','BW_FUZZY_Regeln_Exp3','BW_FUZZY_Regeln_Exp4','BW_FUZZY_Regeln_Exp5','BW_FUZZY_Regeln_Exp6','BW_FUZZY_Regeln_Exp7', 'DATUM', 'Wetter','WIND_RCHTG','WIND_GSCHW','Temperatur', 'Schneehoehe', 'Neuschnee_y', 'xoff', 'yoff', 'Scale', 'ScaleW', 'ScaleH', 'OffX', 'OffY','Lawinencode', 'TEZCode','stdDevExpo','MinExpo','MaxExpo','hozCurvature','verCuvature','totCurvature','MaxRad1','MaxRad15','MaxRad29','MaxRad43','MaxRad57','MaxRad71','MaxRad85','MaxRad99', 'MaxRad113','MaxRad127','MaxRad310','MaxRad324','MaxRad338','MaxRad352','MaxSun1','MaxSun15','MaxSun29','MaxSun43','MaxSun57','MaxSun71','MaxSun85','MaxSun99','MaxSun113','MaxSun127','MaxSun310','MaxSun324','MaxSun338','MaxSun352','HorÜb1','HorÜb2', 'GRNR',  'Bereich_KAPRUN', 'Bemerkung', 'Gebiet', 'Lawinenstrich', 'Text', 'Code_neu', 'Gefahr', 'ZEIT', 'Lawinen_Art', 'Volumen', 'Distanz', 'Wetter_akt_Norm', 'Wetter_akt_Gew', 'Wetter_gestern_Norm', 'Wetter_gestern_Gew', 'Wolken_Gew', 'Niederschlag_Norm', 'Niederschlag_Gew','Schneehöhe_Gew'], axis=1)

# %%
gesamt_df['Avalanche'] =  gesamt_df['ID'].apply(lambda x: 1 if x > 0 else 0)
gesamt_df
# Out:
#           Datum    Intervall  Schneehöhe  Schneehöhe_Norm  Niederschlag  \
# 0    1989-12-20   1989/ 1990        20.0        29.371271           0.0
# 1    1989-12-21   1989/ 1990        19.0        26.654976           0.0
# 2    1989-12-22   1989/ 1990        19.0        27.313567           9.1
# 3    1989-12-23   1989/ 1990         4.0         5.611574           5.3
# 4    1989-12-24   1989/ 1990        10.0        13.894920           7.3
# ...         ...          ...         ...              ...           ...
# 7050        NaT          NaN         NaN              NaN           NaN
# 7051        NaT          NaN         NaN              NaN           NaN
# 7052        NaT          NaN         NaN              NaN           NaN
# 7053        NaT          NaN         NaN              NaN           NaN
# 7054        NaT          NaN         NaN              NaN           NaN
#
#       Lufttemperatur_7h  Lufttemperatur_7h_Norm  Lufttemperatur_7h_Gew  \
# 0                  -1.4                   -11.2                99999.0
# 1                   3.9                    31.2                   -5.6
# 2                   7.6                    60.8                   15.6
# 3                  -6.0                   -48.0                   30.4
# 4                  -5.1                   -40.8                  -24.0
# ...                 ...                     ...                    ...
# 7050                NaN                     NaN                    NaN
# 7051                NaN                     NaN                    NaN
# 7052                NaN                     NaN                    NaN
# 7053                NaN                     NaN                    NaN
# 7054                NaN                     NaN                    NaN
#
#       Lufttemperatur_14h  Lufttemperatur_14h_Norm  ...  Lufttemperatur_last3  \
# 0                    2.6                     20.8  ...              0.000000
# 1                    3.5                     28.0  ...              0.000000
# 2                    4.7                     37.6  ...              0.000000
# 3                   -7.6                    -60.8  ...             15.466667
# 4                   -4.2                    -33.6  ...             28.266667
# ...                  ...                      ...  ...                   ...
# 7050                 NaN                      NaN  ...                   NaN
# 7051                 NaN                      NaN  ...                   NaN
# 7052                 NaN                      NaN  ...                   NaN
# 7053                 NaN                      NaN  ...                   NaN
# 7054                 NaN                      NaN  ...                   NaN
#
#       Lufttemperatur_last4    ID    meanExpo  meanSlope  stdDevSlope  \
# 0                 0.000000   NaN  240.622592  40.215386     6.827700
# 1                 0.000000   NaN   86.721312  43.193687     9.617375
# 2                 0.000000   NaN   95.782919  42.465800     8.184500
# 3                 0.000000   NaN  236.817015  36.165750     5.320700
# 4                15.466667   NaN  271.664767  41.924600     4.659500
# ...                    ...   ...         ...        ...          ...
# 7050                   NaN  32.0  291.038533  44.495709     5.800336
# 7051                   NaN  11.0   83.428097  39.152621     7.412260
# 7052                   NaN   2.0  264.471932  43.070671     8.680311
# 7053                   NaN   8.0  260.468688  42.659900     7.696246
# 7054                   NaN   6.0  298.144745  41.673113     7.147100
#
#        MinSlope   MaxSlope     Altitude  Avalanche
# 0      3.598443  60.656714  2925.378871          0
# 1      0.000000  71.591813  2461.506438          0
# 2      0.000000  61.137880  2423.430860          0
# 3     23.699150  52.545750  2344.716550          0
# 4     33.076000  54.920900  1980.761100          0
# ...         ...        ...          ...        ...
# 7050  15.979145  61.018300  2256.943155          1
# 7051   7.983723  62.527311  2637.086851          1
# 7052   9.192779  69.469879  2887.147429          1
# 7053   7.606200  65.809534  3022.772909          1
# 7054   0.000000  65.409112  2735.163400          1
#
# [7055 rows x 51 columns]

# %%
gesamt_df['ID'] = gesamt_df['ID'].fillna(0)
gesamt_df
# Out:
#           Datum    Intervall  Schneehöhe  Schneehöhe_Norm  Niederschlag  \
# 0    1989-12-20   1989/ 1990        20.0        29.371271           0.0
# 1    1989-12-21   1989/ 1990        19.0        26.654976           0.0
# 2    1989-12-22   1989/ 1990        19.0        27.313567           9.1
# 3    1989-12-23   1989/ 1990         4.0         5.611574           5.3
# 4    1989-12-24   1989/ 1990        10.0        13.894920           7.3
# ...         ...          ...         ...              ...           ...
# 7050        NaT          NaN         NaN              NaN           NaN
# 7051        NaT          NaN         NaN              NaN           NaN
# 7052        NaT          NaN         NaN              NaN           NaN
# 7053        NaT          NaN         NaN              NaN           NaN
# 7054        NaT          NaN         NaN              NaN           NaN
#
#       Lufttemperatur_7h  Lufttemperatur_7h_Norm  Lufttemperatur_7h_Gew  \
# 0                  -1.4                   -11.2                99999.0
# 1                   3.9                    31.2                   -5.6
# 2                   7.6                    60.8                   15.6
# 3                  -6.0                   -48.0                   30.4
# 4                  -5.1                   -40.8                  -24.0
# ...                 ...                     ...                    ...
# 7050                NaN                     NaN                    NaN
# 7051                NaN                     NaN                    NaN
# 7052                NaN                     NaN                    NaN
# 7053                NaN                     NaN                    NaN
# 7054                NaN                     NaN                    NaN
#
#       Lufttemperatur_14h  Lufttemperatur_14h_Norm  ...  Lufttemperatur_last3  \
# 0                    2.6                     20.8  ...              0.000000
# 1                    3.5                     28.0  ...              0.000000
# 2                    4.7                     37.6  ...              0.000000
# 3                   -7.6                    -60.8  ...             15.466667
# 4                   -4.2                    -33.6  ...             28.266667
# ...                  ...                      ...  ...                   ...
# 7050                 NaN                      NaN  ...                   NaN
# 7051                 NaN                      NaN  ...                   NaN
# 7052                 NaN                      NaN  ...                   NaN
# 7053                 NaN                      NaN  ...                   NaN
# 7054                 NaN                      NaN  ...                   NaN
#
#       Lufttemperatur_last4    ID    meanExpo  meanSlope  stdDevSlope  \
# 0                 0.000000   0.0  240.622592  40.215386     6.827700
# 1                 0.000000   0.0   86.721312  43.193687     9.617375
# 2                 0.000000   0.0   95.782919  42.465800     8.184500
# 3                 0.000000   0.0  236.817015  36.165750     5.320700
# 4                15.466667   0.0  271.664767  41.924600     4.659500
# ...                    ...   ...         ...        ...          ...
# 7050                   NaN  32.0  291.038533  44.495709     5.800336
# 7051                   NaN  11.0   83.428097  39.152621     7.412260
# 7052                   NaN   2.0  264.471932  43.070671     8.680311
# 7053                   NaN   8.0  260.468688  42.659900     7.696246
# 7054                   NaN   6.0  298.144745  41.673113     7.147100
#
#        MinSlope   MaxSlope     Altitude  Avalanche
# 0      3.598443  60.656714  2925.378871          0
# 1      0.000000  71.591813  2461.506438          0
# 2      0.000000  61.137880  2423.430860          0
# 3     23.699150  52.545750  2344.716550          0
# 4     33.076000  54.920900  1980.761100          0
# ...         ...        ...          ...        ...
# 7050  15.979145  61.018300  2256.943155          1
# 7051   7.983723  62.527311  2637.086851          1
# 7052   9.192779  69.469879  2887.147429          1
# 7053   7.606200  65.809534  3022.772909          1
# 7054   0.000000  65.409112  2735.163400          1
#
# [7055 rows x 51 columns]

# %%
sns.heatmap(gesamt_df.isna())
# Out:
# <AxesSubplot:>

# %%
gesamt_df.dropna(inplace=True)
sns.heatmap(gesamt_df.isna())
# Out:
# <AxesSubplot:>

# %%
gesamt_df.sort_values(by=['Datum'],inplace=True)
gesamt_df
# Out:
#           Datum    Intervall  Schneehöhe  Schneehöhe_Norm  Niederschlag  \
# 0    1989-12-20   1989/ 1990        20.0        29.371271           0.0
# 1    1989-12-21   1989/ 1990        19.0        26.654976           0.0
# 2    1989-12-22   1989/ 1990        19.0        27.313567           9.1
# 3    1989-12-23   1989/ 1990         4.0         5.611574           5.3
# 4    1989-12-24   1989/ 1990        10.0        13.894920           7.3
# ...         ...          ...         ...              ...           ...
# 7016 2022-02-08   2021/ 2022       175.0       162.359178          16.0
# 7017 2022-02-09   2021/ 2022       155.0       141.483293           8.0
# 7018 2022-02-10   2021/ 2022       149.0       134.537246           0.0
# 7019 2022-02-11   2021/ 2022       144.0       129.792371           0.0
# 7020 2022-02-12   2021/ 2022       149.0       132.381406           7.0
#
#       Lufttemperatur_7h  Lufttemperatur_7h_Norm  Lufttemperatur_7h_Gew  \
# 0                  -1.4                   -11.2                99999.0
# 1                   3.9                    31.2                   -5.6
# 2                   7.6                    60.8                   15.6
# 3                  -6.0                   -48.0                   30.4
# 4                  -5.1                   -40.8                  -24.0
# ...                 ...                     ...                    ...
# 7016               -9.0                   -72.0                  -36.0
# 7017                4.0                    32.0                  -36.0
# 7018               -1.0                    -8.0                   16.0
# 7019               -2.0                   -16.0                   -4.0
# 7020              -14.0                  -112.0                   -8.0
#
#       Lufttemperatur_14h  Lufttemperatur_14h_Norm  ...  Lufttemperatur_last3  \
# 0                    2.6                     20.8  ...              0.000000
# 1                    3.5                     28.0  ...              0.000000
# 2                    4.7                     37.6  ...              0.000000
# 3                   -7.6                    -60.8  ...             15.466667
# 4                   -4.2                    -33.6  ...             28.266667
# ...                  ...                      ...  ...                   ...
# 7016                -1.0                     -8.0  ...            -10.666667
# 7017                 8.0                     64.0  ...            -40.000000
# 7018                 1.0                      8.0  ...            -80.000000
# 7019                -6.0                    -48.0  ...            -29.333333
# 7020                 0.0                      0.0  ...             45.333333
#
#       Lufttemperatur_last4    ID    meanExpo  meanSlope  stdDevSlope  \
# 0                 0.000000   0.0  240.622592  40.215386     6.827700
# 1                 0.000000   0.0   86.721312  43.193687     9.617375
# 2                 0.000000   0.0   95.782919  42.465800     8.184500
# 3                 0.000000   0.0  236.817015  36.165750     5.320700
# 4                15.466667   0.0  271.664767  41.924600     4.659500
# ...                    ...   ...         ...        ...          ...
# 7016              2.666667  33.0   62.004911  41.474100     8.876500
# 7017            -10.666667   0.0   86.721312  43.193687     9.617375
# 7018            -40.000000   0.0    2.980625  37.066700     6.003100
# 7019            -80.000000   0.0   98.851562  41.040858     8.651008
# 7020            -29.333333   0.0    2.980625  37.066700     6.003100
#
#        MinSlope   MaxSlope     Altitude  Avalanche
# 0      3.598443  60.656714  2925.378871          0
# 1      0.000000  71.591813  2461.506438          0
# 2      0.000000  61.137880  2423.430860          0
# 3     23.699150  52.545750  2344.716550          0
# 4     33.076000  54.920900  1980.761100          0
# ...         ...        ...          ...        ...
# 7016   1.418093  65.950220  2223.063053          1
# 7017   0.000000  71.591813  2461.506438          0
# 7018  13.586900  50.025850  1967.563900          0
# 7019   6.873767  71.013708  2637.582267          0
# 7020  13.586900  50.025850  1967.563900          0
#
# [7021 rows x 51 columns]

# %%
#gesamt_df[["Intervall", "Avalanche"]].groupby("Intervall").sum()

# %%
#gesamt_df["Avalanche"].sum()

# %%
#smaller_1989 = gesamt_df.loc[gesamt_df['Datum'] < dt.datetime.strptime('1989-10-01 00:00:00', '%Y-%m-%d %H:%M:%S')]
#smaller_1989[["Intervall", "Avalanche"]].groupby("Intervall").sum()['Avalanche'].mean()

# %%
#larger_1989 = gesamt_df.loc[gesamt_df['Datum'] > dt.datetime.strptime('1989-10-01 00:00:00', '%Y-%m-%d %H:%M:%S')]
#larger_1989[["Intervall", "Avalanche"]].groupby("Intervall").sum()['Avalanche'].mean()

# %%
gesamt_df.to_csv('newData/gesamt_set_1.csv', index=False)
gesamt_df
# Out:
#           Datum    Intervall  Schneehöhe  Schneehöhe_Norm  Niederschlag  \
# 0    1989-12-20   1989/ 1990        20.0        29.371271           0.0
# 1    1989-12-21   1989/ 1990        19.0        26.654976           0.0
# 2    1989-12-22   1989/ 1990        19.0        27.313567           9.1
# 3    1989-12-23   1989/ 1990         4.0         5.611574           5.3
# 4    1989-12-24   1989/ 1990        10.0        13.894920           7.3
# ...         ...          ...         ...              ...           ...
# 7016 2022-02-08   2021/ 2022       175.0       162.359178          16.0
# 7017 2022-02-09   2021/ 2022       155.0       141.483293           8.0
# 7018 2022-02-10   2021/ 2022       149.0       134.537246           0.0
# 7019 2022-02-11   2021/ 2022       144.0       129.792371           0.0
# 7020 2022-02-12   2021/ 2022       149.0       132.381406           7.0
#
#       Lufttemperatur_7h  Lufttemperatur_7h_Norm  Lufttemperatur_7h_Gew  \
# 0                  -1.4                   -11.2                99999.0
# 1                   3.9                    31.2                   -5.6
# 2                   7.6                    60.8                   15.6
# 3                  -6.0                   -48.0                   30.4
# 4                  -5.1                   -40.8                  -24.0
# ...                 ...                     ...                    ...
# 7016               -9.0                   -72.0                  -36.0
# 7017                4.0                    32.0                  -36.0
# 7018               -1.0                    -8.0                   16.0
# 7019               -2.0                   -16.0                   -4.0
# 7020              -14.0                  -112.0                   -8.0
#
#       Lufttemperatur_14h  Lufttemperatur_14h_Norm  ...  Lufttemperatur_last3  \
# 0                    2.6                     20.8  ...              0.000000
# 1                    3.5                     28.0  ...              0.000000
# 2                    4.7                     37.6  ...              0.000000
# 3                   -7.6                    -60.8  ...             15.466667
# 4                   -4.2                    -33.6  ...             28.266667
# ...                  ...                      ...  ...                   ...
# 7016                -1.0                     -8.0  ...            -10.666667
# 7017                 8.0                     64.0  ...            -40.000000
# 7018                 1.0                      8.0  ...            -80.000000
# 7019                -6.0                    -48.0  ...            -29.333333
# 7020                 0.0                      0.0  ...             45.333333
#
#       Lufttemperatur_last4    ID    meanExpo  meanSlope  stdDevSlope  \
# 0                 0.000000   0.0  240.622592  40.215386     6.827700
# 1                 0.000000   0.0   86.721312  43.193687     9.617375
# 2                 0.000000   0.0   95.782919  42.465800     8.184500
# 3                 0.000000   0.0  236.817015  36.165750     5.320700
# 4                15.466667   0.0  271.664767  41.924600     4.659500
# ...                    ...   ...         ...        ...          ...
# 7016              2.666667  33.0   62.004911  41.474100     8.876500
# 7017            -10.666667   0.0   86.721312  43.193687     9.617375
# 7018            -40.000000   0.0    2.980625  37.066700     6.003100
# 7019            -80.000000   0.0   98.851562  41.040858     8.651008
# 7020            -29.333333   0.0    2.980625  37.066700     6.003100
#
#        MinSlope   MaxSlope     Altitude  Avalanche
# 0      3.598443  60.656714  2925.378871          0
# 1      0.000000  71.591813  2461.506438          0
# 2      0.000000  61.137880  2423.430860          0
# 3     23.699150  52.545750  2344.716550          0
# 4     33.076000  54.920900  1980.761100          0
# ...         ...        ...          ...        ...
# 7016   1.418093  65.950220  2223.063053          1
# 7017   0.000000  71.591813  2461.506438          0
# 7018  13.586900  50.025850  1967.563900          0
# 7019   6.873767  71.013708  2637.582267          0
# 7020  13.586900  50.025850  1967.563900          0
#
# [7021 rows x 51 columns]
